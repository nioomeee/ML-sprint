# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

text = "The striped bats are hanging on their feet for best."
print(f"Original: \n {text}")

# STEP 1: Tokenization
tokens = word_tokenize(text)
print(f"\n1. Tokens: {tokens}")

# STEP 2: Stemming
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in tokens]
print(f"\n2. Stemmed words: {stemmed_words}")

# STEP 3: Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print(f"\n3. Lemmatized words: {lemmatized_words}")
# Out:
# Original:
#  The striped bats are hanging on their feet for best.
#
# 1. Tokens: ['The', 'striped', 'bats', 'are', 'hanging', 'on', 'their', 'feet', 'for', 'best', '.']
#
# 2. Stemmed words: ['the', 'stripe', 'bat', 'are', 'hang', 'on', 'their', 'feet', 'for', 'best', '.']
#
# 3. Lemmatized words: ['The', 'striped', 'bat', 'are', 'hanging', 'on', 'their', 'foot', 'for', 'best', '.']
